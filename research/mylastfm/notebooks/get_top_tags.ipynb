# %%
# Add parent directory to SYS to be able to import modules
import sys
sys.path.append("../")

# %%
from pathlib import Path
import dataloading
import preprocessing

# %%
DATA_DIR = Path("../../../data")

# %%
lastfm_tag_probs = dataloading.read_tag_probs(
    DATA_DIR, num_tags=1000, dimension="track", index_col="track"
)

preprocessing.clean_column_names(lastfm_tag_probs)

lastfm_tag_probs = lastfm_tag_probs.iloc[:1,:-12]

# %%
list(lastfm_tag_probs.columns)
# Out:
# ['electronic',
#  'ambient',
#  'electronica',
#  'chillout',
#  'indie',
#  'seen live',
#  'house',
#  'techno',
#  'dance',
#  'electro',
#  'minimal',
#  'alternative',
#  'rock',
#  'downtempo',
#  'trip-hop',
#  'experimental',
#  'trance',
#  'pop',
#  'idm',
#  'female vocalists',
#  'deep house',
#  'instrumental',
#  'british',
#  'indie rock',
#  'lounge',
#  'soundtrack',
#  'minimal techno',
#  'jazz',
#  'synthpop',
#  'funk',
#  'disco',
#  'french',
#  'indie pop',
#  'tech house',
#  'psychedelic',
#  'alternative rock',
#  'chill',
#  'hip-hop',
#  'electropop',
#  '80s',
#  'soul',
#  '90s',
#  'shoegaze',
#  'new age',
#  'progressive house',
#  'new wave',
#  'dream pop',
#  'electroclash',
#  'acid jazz',
#  'chillwave',
#  'indietronica',
#  '00s',
#  'classic rock',
#  'lo-fi',
#  'progressive trance',
#  'progressive rock',
#  'beautiful',
#  'atmospheric',
#  'american',
#  'post-punk',
#  'german',
#  'nu disco',
#  'kompakt',
#  'breakbeat',
#  'britpop',
#  'post-rock',
#  'dreamy',
#  'swedish',
#  'mellow',
#  'spanish',
#  'big beat',
#  'krautrock',
#  'piano',
#  'singer-songwriter',
#  'trip hop',
#  'nu jazz',
#  'remix',
#  'all',
#  'dubstep',
#  'canadian',
#  'uk',
#  'hip hop',
#  'club',
#  'male vocalists',
#  'folk',
#  'glitch',
#  'synth pop',
#  'rap',
#  'funky',
#  'classical',
#  'latin',
#  'sexy',
#  'norwegian',
#  '70s',
#  '10s',
#  'love',
#  'drone',
#  'party',
#  'punk',
#  'awesome',
#  'somafm',
#  'fip',
#  'space disco',
#  'dub',
#  'favorites',
#  'australian',
#  'vocal trance',
#  'electro house',
#  'relax',
#  'blues',
#  'cool',
#  'epic',
#  'world',
#  'drum and bass',
#  'nu-disco',
#  'hard rock',
#  'new rave',
#  'psychedelic rock',
#  'industrial',
#  'progressive',
#  'easy listening',
#  'summer',
#  'microhouse',
#  'synth',
#  'reggae',
#  'ethereal',
#  'contemporary classical',
#  '4 stars',
#  'nu-jazz',
#  'italo disco',
#  'rnb',
#  'france',
#  'acoustic',
#  'usa',
#  '60s',
#  'female vocalist',
#  'ambient techno',
#  'tech-house',
#  'fm4',
#  'breaks',
#  'relaxing',
#  'chill out',
#  'deep',
#  'melancholy',
#  'groove',
#  'groovy',
#  'love at first listen',
#  'spotify',
#  'oldies',
#  'under 2000 listeners',
#  'french house',
#  '2010',
#  'noise',
#  'metal',
#  'garage rock',
#  'germany',
#  'beats',
#  'punk rock',
#  'cover',
#  'personal favourites',
#  'vugube62',
#  'melancholic',
#  'balearic',
#  'deep techno',
#  'metro downtempo',
#  'favorite',
#  'composer',
#  'female vocals',
#  'happy',
#  'detroit',
#  'japanese',
#  'acid',
#  'moby',
#  'bpitch control',
#  'indie electronic',
#  'fusion',
#  'fun',
#  'english',
#  '1live fiehe',
#  'detroit techno',
#  'modern classical',
#  'uplifting trance',
#  'eurodance',
#  'avant-garde',
#  '2010s',
#  'dub techno',
#  'psytrance',
#  'favourites',
#  'minimal house',
#  'melodic',
#  'england',
#  'loved',
#  'grunge',
#  'catchy',
#  'electro pop',
#  'berlin',
#  'brazilian',
#  'funky house',
#  'ninja tune',
#  'dark',
#  '2011',
#  'disco house',
#  'favourite',
#  'italian',
#  'neoclassical',
#  '10 of 10 stars',
#  'downbeat',
#  'heavy metal',
#  'electro-pop',
#  'melodic trance',
#  'turntablism',
#  'bossa nova',
#  'acid house',
#  'jazzy',
#  'dance-punk',
#  'dj',
#  'dark ambient',
#  'neotrance',
#  'psychill',
#  'nice',
#  'pop rock',
#  'minimalism',
#  'guitar',
#  'smooth',
#  'danish',
#  'progressive electronic',
#  'hardcore',
#  'amazing',
#  'female',
#  'border community',
#  'icelandic',
#  'classic',
#  'art rock',
#  'future garage',
#  'synthwave',
#  'balearic beat',
#  'acid lounge',
#  'chill chill',
#  'my-love',
#  'lounge electronic',
#  'chillair',
#  'tango',
#  'space rock',
#  'tropcool',
#  'scandinavian',
#  'space',
#  'alternative lounge',
#  'serve chilled',
#  'lounge at home tres',
#  'nujazz',
#  'city lounge',
#  'groove lounge',
#  'world music',
#  'new york',
#  'my lounge room',
#  'chillounge1',
#  'lounge chill',
#  'instrumental hip-hop',
#  'acoustic groove',
#  'epic lounge',
#  'dance punk',
#  'space ambient',
#  'lounge-tech',
#  'belgian',
#  'scottish',
#  'spanish indie pop',
#  'nu metal',
#  'vocal',
#  'indie dance',
#  'sad',
#  'smoothly sexy sounding',
#  'hypnotic',
#  'dutch',
#  'smooth lounge',
#  'folktronica',
#  'electronic lounge jazz',
#  'uplifting',
#  'ouahhhhh',
#  'lounge downtempo',
#  'darkwave',
#  'lounge uptempo',
#  'sexy sounding',
#  'dreamwave',
#  'jazzy flavoured',
#  'deutsch',
#  'daft punk',
#  'score',
#  '8 of 10 stars',
#  '2013',
#  '2012',
#  'ed banger',
#  'upbeat',
#  'jazz-trip',
#  'best of chill',
#  '1st vine',
#  'jazzy vibes',
#  'uutta jazzia',
#  'heard on pandora',
#  'abstract',
#  'glam rock',
#  'orchestral',
#  'blues rock',
#  'chillout downtempo',
#  'love it',
#  'best of down tempo',
#  'retro',
#  'awesome downtempo',
#  'best of downtempo',
#  'ambient house',
#  'glo-fi',
#  'warp',
#  'underground hip-hop',
#  'synth-pop',
#  'downtempo influences',
#  'alternative dance',
#  'ost',
#  'post rock',
#  'rave',
#  'drum n bass',
#  'genre: downtempo',
#  'bass',
#  'vocal house',
#  '2009',
#  'genre:downtempo',
#  'post-classical',
#  'belgium',
#  'lounge at home two',
#  'uuta jazzia',
#  'sweet downtempo',
#  'uutta jazziz',
#  'fav',
#  'elektro',
#  'dream',
#  'played',
#  'french touch',
#  'surf rock',
#  'trippy',
#  'london',
#  'cinematic',
#  'neo-psychedelia',
#  'good',
#  'spain',
#  'soundtracks',
#  'lizvelrene2010',
#  'soulful house',
#  'sweden',
#  'jecks',
#  'romantic',
#  'groovesalad',
#  'poptron',
#  'jazz fusion',
#  'british i like',
#  'psychedelic pop',
#  'leftfield',
#  'sweet',
#  'finnish',
#  'electronic-lounge',
#  'goa',
#  'surf',
#  'birp',
#  '1st vine acid',
#  'lovely',
#  'calm',
#  'chilllounge1',
#  'elektronic beats',
#  'swing',
#  'composers',
#  'canada',
#  'nu-bluz funky grooves in the e-lounge',
#  'lounge vibe',
#  'cafe del mar',
#  'sex',
#  'old school',
#  'dnb',
#  'covers',
#  'edm',
#  'bagel',
#  'alt-country',
#  'driving',
#  'ska',
#  '2008',
#  'united kingdom',
#  'haunting',
#  'stoner rock',
#  '2000s',
#  'iiiiiiiiii amazing track :d iiiiiiiiii',
#  'lounge groove',
#  'spring',
#  'male vocals',
#  'soft rock',
#  'genius',
#  'electronic superhighway',
#  'rhythm and blues',
#  'interesting',
#  'hard trance',
#  'french electro',
#  'art pop',
#  'eclectonia',
#  'electro disco',
#  'nu jazz vibe',
#  'nujazz vibe',
#  'nu-jazz vibe',
#  'electro-house',
#  'neo-classical',
#  'metro electronica',
#  'acid jazz vibe',
#  'favorite songs',
#  'design',
#  '6 of 10 stars',
#  'electronic rock',
#  'elektronischer-b0lzen',
#  'vangelis',
#  'electro funk',
#  'served chilled',
#  'dfa',
#  'space music',
#  'indietronic',
#  'electropcool',
#  'smooth jazz',
#  'chilled',
#  'rainy day',
#  'warm',
#  'electrocool',
#  'salsa',
#  'best',
#  'irish',
#  'jungle',
#  'fave indie pop',
#  'goldfrapp',
#  'nostalgic',
#  'lounge jazz vibe',
#  'rock and roll',
#  'future jazz',
#  'uk garage',
#  'latin jazz',
#  'energetic',
#  'future jazz vibe',
#  'jazz hop',
#  'noise pop',
#  '2016 single',
#  'down-tempo vibe',
#  'canadiangdchill',
#  'soft',
#  'downtempo vibe',
#  'downtempo lounge',
#  'i am a party girl here is my soundtrack',
#  'jazzy trip',
#  'garage',
#  'vocal jazz',
#  'dream trance',
#  'spanish rock',
#  'male vocalist',
#  'emo',
#  'political',
#  'cosmic',
#  'dreampop',
#  'perfect',
#  'great',
#  'madchester',
#  'best of down temp',
#  'manchester',
#  'contemporary',
#  'game',
#  'twee',
#  'emotional',
#  'norway',
#  'winter',
#  'minimal techno artists',
#  'jazz funk',
#  'ebm',
#  'hiphop',
#  'tribal',
#  'electronic music',
#  'contemporary piano',
#  'r&b',
#  'jazzy down-tempo vibe',
#  'jazzy downtempo vibe',
#  'lush',
#  'ambient pop',
#  'greek',
#  '2007',
#  'feel good',
#  '2014',
#  'trumpet',
#  'indie folk',
#  'easy',
#  'polish',
#  'gilles peterson',
#  'live',
#  'world fusion',
#  'gilbert',
#  '-favorites-',
#  'portuguese',
#  'experimental electronic',
#  'california',
#  'sleep',
#  'ion b chill station',
#  'witch house',
#  'femalevocalistsgdchill',
#  'nostalgia',
#  'soundscape',
#  'late night',
#  'electronicadance',
#  'triphop',
#  'minimalist',
#  'lesser known yet streamable artists',
#  'math rock',
#  'minimal electro',
#  'downtempo groove',
#  'jazzy down tempo vibe',
#  'good stuff',
#  'italo-disco',
#  'black metal',
#  'chillosophy',
#  'country',
#  'rapcore',
#  'australia',
#  'quirky',
#  'psychedelic trance',
#  'film score',
#  'pixies palace',
#  'dancehall',
#  'experimental rock',
#  'electro rock',
#  'alternative  punk',
#  'ambient trance',
#  'check out',
#  'noise rock',
#  'streamable track wants',
#  'go drunk eosin cabs',
#  'netherlands',
#  'disco punk',
#  'southern rock',
#  'african',
#  'favourite songs',
#  'duo',
#  'down tempo',
#  'swiss',
#  'coldwave',
#  '2015',
#  'fotomotor',
#  'drive',
#  'amayzes loved',
#  'dance rock',
#  '-electronic-',
#  'neo-soul',
#  'favourite remixes',
#  'urban',
#  '2002',
#  "80's",
#  'glitch-hop',
#  'italy',
#  'remixes',
#  'boards of canada',
#  'lovedbybeyondwithin',
#  'funky breaks',
#  'female vocal',
#  '8-bit',
#  'minimal synth',
#  'folk rock',
#  'vocal-lounge',
#  'brooklyn',
#  'the music maker society',
#  'new',
#  'brilliant',
#  'magic',
#  'kitsune',
#  'italo',
#  'crossover',
#  'metro funky',
#  'deep minimal techhouse',
#  'jazz-pop',
#  'banned',
#  'cute',
#  'chicago house',
#  'francais',
#  'tech',
#  'chanson francaise',
#  'saxophone',
#  'night',
#  'mashup',
#  'fucking awesome',
#  'proto-punk',
#  'nu-bluz',
#  'sensual',
#  'motown',
#  'artificial lounge',
#  'minimal tech house',
#  'gay',
#  'vocal downtempo',
#  'masterpiece',
#  'postclassical',
#  'ibiza',
#  'like',
#  'cuban',
#  '9 of 10 stars',
#  'brasil',
#  'rock n roll',
#  'nu rave',
#  'energy_x',
#  'handclaps',
#  'psybient',
#  'boogie',
#  'new zealand',
#  'hauntology',
#  'dope',
#  'cologne',
#  '1',
#  'abstract hip-hop',
#  'melodic techno',
#  'air',
#  'thrash metal',
#  'electrorock',
#  'russian',
#  'funk rock',
#  'underground hip hop',
#  'post punk',
#  'eletronic',
#  'wow',
#  'spoken word',
#  '3',
#  'alternative metal',
#  'royksopp',
#  'kl4bb1n d0wn',
#  'check this out',
#  'synthwave 4x4',
#  'slow',
#  'ballad',
#  '50s',
#  'liquid funk',
#  'metamorphosis: brainchildliving sacrificecircle of dust',
#  'deep and dark',
#  '4',
#  'alternative pop',
#  'elektro target',
#  'new york city',
#  'dance party',
#  'gothic',
#  'americana',
#  'central point',
#  'electric barbarella',
#  'experimental techno',
#  'electrohouse',
#  'synthesizer',
#  'best of 2013',
#  'brazil',
#  'totec radio',
#  'mnml',
#  'other',
#  'memories',
#  'moody',
#  'misc',
#  'chill-out',
#  '21st century',
#  'post classical',
#  'meditation',
#  'progressive breaks',
#  'power pop',
#  '2017',
#  'jazzy female vocal',
#  'disco funk',
#  'neo classical',
#  'over 5 minutes long',
#  'wonky',
#  'depeche mode',
#  'portugal',
#  'rock argentino',
#  'rayharel',
#  'argentina',
#  'fractal',
#  'club house',
#  'chamber pop',
#  'hiccup',
#  'maximinimal',
#  'strings',
#  'best of 2014',
#  'animals',
#  'best of 2010',
#  'soulwax',
#  'soundscapers',
#  'vule',
#  'funky disco',
#  'ghostly international',
#  'cosmic disco',
#  "90's",
#  'algebraic',
#  'artists who are lastfm user',
#  'ethnic',
#  'best of 2009',
#  'celtic',
#  'electropunk',
#  'mondiovision',
#  'detroit house',
#  'dance pop',
#  'electro-rock',
#  'death metal',
#  'soundtrackgdchill',
#  'morning',
#  'sunday morning',
#  'european',
#  '2005',
#  'psychoalgie',
#  'great remix',
#  'dance-pop',
#  'soulful',
#  'dial',
#  'feelgood',
#  'secretagent',
#  'beat',
#  'grime',
#  'not electro',
#  'broken beat',
#  'chicago',
#  'the chemical brothers',
#  'house music',
#  'eargasm',
#  '2015 single',
#  'underground',
#  'psyhaus',
#  'doom metal',
#  'vaporwave',
#  'best song ever',
#  'spanish indie',
#  'mike oldfield',
#  'mestizo',
#  'best of 2012',
#  'top gear',
#  'radiohead',
#  'jazz vocal',
#  'ephesians',
#  'japan',
#  'independent artists',
#  'm83',
#  'sunset',
#  'post-dubstep',
#  '2000',
#  'rainforest music on your internet radio',
#  'free mp3 artist radio',
#  'eremuse - sgististj',
#  'aeo',
#  'jazz-funk',
#  '_3',
#  'funny',
#  'barcelona',
#  'dasjonnas favorites',
#  'electrofunk',
#  'eremuse - sgjstistj',
#  'ambient piano',
#  'piano ambient',
#  'best of 2011',
#  'colobocuro',
#  'eclectic',
#  'lol',
#  'contemporary instrumental',
#  'lovedbygdchill',
#  'classic trance',
#  'adrien wayne',
#  'autumn',
#  'freak folk',
#  'chanson',
#  'indie disco',
#  'melodic house',
#  'top',
#  'video game music',
#  'electro-disco',
#  'post-punk revival',
#  'united states',
#  'uptempo',
#  '2017 single',
#  'single tracks',
#  '5 stars',
#  '4 of 10 stars',
#  'bittersweet',
#  'indietonic',
#  'electglitchdubhop',
#  'metro minimal',
#  'montreal',
#  'gilbert linley',
#  'nyc',
#  '-new-age-and-ambient-',
#  'thrash',
#  'floating',
#  'retro electro',
#  'krautronica',
#  'the knife',
#  'modern classic',
#  'deep ambient',
#  'soothing',
#  'glam',
#  '1990s',
#  'guilty pleasure',
#  'deep-clash',
#  'discopunk',
#  'chez musinum',
#  'kat fm',
#  'massive attack',
#  'paul van dyk',
#  'skins',
#  'cool jazz',
#  'movie',
#  'best of 2007',
#  '2006',
#  '4ad',
#  'fuck yeah',
#  'alternative hip-hop',
#  'gothic rock',
#  'denmark',
#  'test',
#  'work',
#  'spanish pop',
#  'hot',
#  'scotland',
#  'frauen und technik',
#  'james horner',
#  'does allah have a penis',
#  'underworld',
#  'riot grrrl',
#  'neo disco',
#  'music to get the pussy wet',
#  'electrogefuckel',
#  'movie score composers',
#  'deephouse',
#  'afrobeat',
#  'discover',
#  'mistagged',
#  'danceable',
#  'new romantic',
#  'gorillaz',
#  'techno for depressed people',
#  'rock en espanol',
#  'j-pop',
#  'ambient dub',
#  'instrumental hip hop',
#  '7 of 10 stars',
#  'i like',
#  'motorik',
#  'techhouse',
#  'colours',
#  'davaho53',
#  'addictive',
#  'early morning music',
#  'critically acclaimed song',
#  'download',
#  'trip',
#  'night music',
#  'progressive psytrance',
#  'hardcore punk',
#  'choir',
#  'mysticplaces',
#  'percussion',
#  'berlin school',
#  'brazilectro',
#  'intense',
#  'late night music',
#  'dance dance dance',
#  'big band',
#  'drums',
#  'avantgarde',
#  'russia',
#  'los angeles',
#  'venezuela',
#  'traum',
#  'freedom',
#  'peaceful',
#  'beats in space',
#  'to listen',
#  'yahshua',
#  'kick your ass',
#  'hot chip',
#  'cave 12',
#  'vintage synths',
#  'techno house',
#  '2001',
#  'strawbalesugarcube',
#  'best of 2016',
#  'zicelectro',
#  'good music',
#  'arguman-loved tracks',
#  'scatter funk',
#  'postrap',
#  'tantotempotaste',
#  'pretty',
#  'its great when youre 08 yeah',
#  'portishead',
#  'haeuslicher-b0lzen',
#  '12',
#  'to listen to',
#  'recos',
#  '1992',
#  'to the one i still dont know who',
#  'uk funky',
#  'academy award winner',
#  'samples',
#  '9',
#  'male',
#  'baroque pop',
#  'espanol',
#  'good shit',
#  '10',
#  'yeah',
#  'hairy chest',
#  'network',
#  'good mood',
#  'digitalis',
#  'weird',
#  'eyelid tones',
#  'vocoder',
#  'zicbouge',
#  'pink floyd',
#  'electronic pop',
#  'classic house',
#  'acid techno',
#  'hann with gun',
#  'oscar best original score',
#  'producer',
#  'deep tech',
#  'super',
#  'radiohead office chart',
#  'lost in translation',
#  'goth',
#  'wake-up song',
#  'goa trance',
#  'new age aesthetics',
#  'fabric',
#  'slowcore',
#  'delicious',
#  'spacey',
#  'perfection',
#  'shoegazer',
#  'the xx',
#  'ion b radio',
#  'electrotango',
#  'j',
#  'enos',
#  'latino',
#  'kraftwerk',
#  'polyaztone',
#  'happiness',
#  'worked with',
#  'electro techno',
#  'oasis',
#  'zouk',
#  '2016',
#  '2003',
#  'new age and ambient',
#  'san francisco',
#  'progressive metal',
#  'breakcore',
#  'the netherlands',
#  '17',
#  'makes me happy',
#  'audioase',
#  'tribal house',
#  'tune',
#  '80',
#  '1998',
#  'breaking bad',
#  'post-hardcore',
#  'violin',
#  'love songs',
#  'atmosphere',
#  'electro minimal',
#  'austria',
#  'mysterious',
#  'inception',
#  'magical',
#  'drum & bass',
#  'samba',
#  'minimal ambient',
#  'pop-rock',
#  'creative commons',
#  'electrease',
#  '6',
#  'powerful',
#  'bbc radio1 playlist 2016',
#  'anytime is housetime',
#  'belgisch',
#  'hit',
#  'lecimy w kosmos',
#  'underground rap',
#  'uk bass',
#  'damned good',
#  'trent reznor',
#  'bigbeat',
#  'movie soundtrack',
#  'one of the best',
#  'american i like',
#  'hamburg',
#  'beach',
#  'ambient electronica',
#  'mix',
#  'music',
#  '8',
#  '7',
#  'named according to stretchead',
#  'sun and moon and stars and outer space',
#  'valerie',
#  'nu-metal',
#  'epic trance',
#  'schellack-schatz']
