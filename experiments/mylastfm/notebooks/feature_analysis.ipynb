# %% [markdown]
# # Spotify Features

# %%
import pandas as pd
import seaborn as sns

sns.set_theme()

# %% [markdown]
# #

# %%
# Load one of the datasets by track
data = pd.read_csv("../../../data/jaime_lastfm/merged_100_tag_probs_by_track.csv")

# %%
import matplotlib.pyplot as plt
variables = ["danceability","energy","acousticness","instrumentalness","valence"]
lines = ["-","--", "dashdot", "-", ":"]

for v, linestyle in zip(variables, lines):
    print(f"# {v}")
    print(" Mean:", data[v].mean())
    print(" Std:", data[v].std())
    ax = data[v].plot.kde(figsize=(10,10), label=v, linestyle=linestyle)
    ax.set_xlim(0,1)
    #ax.legend([variables])

plt.legend(variables)
plt.show()
# Out:
# # danceability
#  Mean: 0.5991956667618505
#  Std: 0.1925507021422637
# # energy
#  Mean: 0.6313359660194158
#  Std: 0.23340814353591097
# # acousticness
#  Mean: 0.220746500485437
#  Std: 0.302224998984079
# # instrumentalness
#  Mean: 0.5143905239141933
#  Std: 0.3824632244160016
# # valence
#  Mean: 0.43586859651627835
#  Std: 0.27935989005970785
